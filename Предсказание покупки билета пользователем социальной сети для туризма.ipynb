# %% [markdown]
# # 1. Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Tourism Customer Behaviour.csv')

df.columns = ['ID пользователя', 'Купил ли билет',
              'Среднегодовое число просмотра туристических сайтов',
              'Предпочитаемое устройство для авторизации',
              'Число лайков на связанные с туризмом публикации за последний год',
              'Среднегодовое число туристических поездок',
              'Число членов семьи', 'Предпочитаемый вид отдыха',
              'Среднеговое число комментариев к связанным с туризмом публикациям',
              'Число лайков на туристические публикации пользователя',
              'Число прошедших после крайней поездки недель',
              'Разегистрирован ли в «нашей» соцсети',
              'Среднемесячное число лайков в «нашей» соцсети', 'Трудоустроен ли',
              'Наличие интересующихся туризмом друзей (1 — много, 4 — мало)',
              'Подросток ли', 'Среднее время, проведённое в «нашей» соцсети']

df.sample(5)
# Out:
#        ID пользователя Купил ли билет  \
# 2902           1002903             No
# 3103           1003104             No
# 442            1000443             No
# 10482          1010483            Yes
# 8035           1008036             No
#
#        Среднегодовое число просмотра туристических сайтов  \
# 2902                                               277.0
# 3103                                               429.0
# 442                                                270.0
# 10482                                              269.0
# 8035                                               203.0
#
#       Предпочитаемое устройство для авторизации  \
# 2902                            iOS and Android
# 3103                            iOS and Android
# 442                                     ANDROID
# 10482                                       Tab
# 8035                                     Laptop
#
#        Число лайков на связанные с туризмом публикации за последний год  \
# 2902                                                 NaN
# 3103                                             11729.0
# 442                                              22225.0
# 10482                                            19502.0
# 8035                                             44908.0
#
#       Среднегодовое число туристических поездок Число членов семьи  \
# 2902                                         10                  3
# 3103                                         24                  2
# 442                                          10                  4
# 10482                                        23                  2
# 8035                                          1                  3
#
#       Предпочитаемый вид отдыха  \
# 2902                  Financial
# 3103                  Financial
# 442                     Medical
# 10482                     Beach
# 8035            Historical site
#
#        Среднеговое число комментариев к связанным с туризмом публикациям  \
# 2902                                                42.0
# 3103                                                89.0
# 442                                                 32.0
# 10482                                               74.0
# 8035                                                62.0
#
#        Число лайков на туристические публикации пользователя  \
# 2902                                               13744
# 3103                                                9484
# 442                                                 9980
# 10482                                               5965
# 8035                                                4300
#
#        Число прошедших после крайней поездки недель  \
# 2902                                              1
# 3103                                              3
# 442                                               1
# 10482                                             3
# 8035                                              1
#
#       Разегистрирован ли в «нашей» соцсети  \
# 2902                                   Yes
# 3103                                   Yes
# 442                                     No
# 10482                                  Yes
# 8035                                    No
#
#        Среднемесячное число лайков в «нашей» соцсети Трудоустроен ли  \
# 2902                                              25             Yes
# 3103                                              25              No
# 442                                               14              No
# 10482                                             26              No
# 8035                                              19              No
#
#        Наличие интересующихся туризмом друзей (1 — много, 4 — мало)  \
# 2902                                                   1
# 3103                                                   2
# 442                                                    4
# 10482                                                  1
# 8035                                                   2
#
#        Подросток ли  Среднее время, проведённое в «нашей» соцсети
# 2902            1.0                                          16.0
# 3103            1.0                                          17.0
# 442             0.0                                          10.0
# 10482           0.0                                          10.0
# 8035            0.0                                           7.0

# %% [markdown]
# ## 1.1. Разведочный анализ данных

# %%
print(f'В датафрейме {df.shape[0]} строк (пользователей) и {df.shape[1]} \
столбцов (характеристик пользователей)')
# Out:
# В датафрейме 11760 строк (пользователей) и 17 столбцов (характеристик пользователей)

# %% [markdown]
# Очевидно, ID пользователя ничего не даст нам для прогноза его покупки — удалим данный столбец.

# %%
df.drop('ID пользователя', axis=1, inplace=True)

# %% [markdown]
# Посмотрим, какие признаки пропущены у некоторых объектов выборки (и сколько процентов пропущенные строки занимают от всей выборки). Видим, что количество пропусков не столь значительное.

# %%
for col in df.columns[df.isna().any()]:
  print(f'{col}: \t {(df[col].isna().sum() / len(df) * 100):.2f}%')
# Out:
# Среднегодовое число просмотра туристических сайтов: 	 4.94%
# Предпочитаемое устройство для авторизации: 	 0.45%
# Число лайков на связанные с туризмом публикации за последний год: 	 3.24%
# Среднегодовое число туристических поездок: 	 0.64%
# Предпочитаемый вид отдыха: 	 0.26%
# Среднеговое число комментариев к связанным с туризмом публикациям: 	 1.75%
# Разегистрирован ли в «нашей» соцсети: 	 0.88%
# Подросток ли: 	 0.01%
# Среднее время, проведённое в «нашей» соцсети: 	 0.01%

# %% [markdown]
# ## 1.2. Предобработка данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Купил ли билет                                                     11760 non-null  object
#  1   Среднегодовое число просмотра туристических сайтов                 11179 non-null  float64
#  2   Предпочитаемое устройство для авторизации                          11707 non-null  object
#  3   Число лайков на связанные с туризмом публикации за последний год   11379 non-null  float64
#  4   Среднегодовое число туристических поездок                          11685 non-null  object
#  5   Число членов семьи                                                 11760 non-null  object
#  6   Предпочитаемый вид отдыха                                          11729 non-null  object
#  7   Среднеговое число комментариев к связанным с туризмом публикациям  11554 non-null  float64
#  8   Число лайков на туристические публикации пользователя              11760 non-null  int64
#  9   Число прошедших после крайней поездки недель                       11760 non-null  int64
#  10  Разегистрирован ли в «нашей» соцсети                               11657 non-null  object
#  11  Среднемесячное число лайков в «нашей» соцсети                      11760 non-null  int64
#  12  Трудоустроен ли                                                    11760 non-null  object
#  13  Наличие интересующихся туризмом друзей (1 — много, 4 — мало)       11760 non-null  int64
#  14  Подросток ли                                                       11759 non-null  float64
#  15  Среднее время, проведённое в «нашей» соцсети                       11759 non-null  float64
# dtypes: float64(5), int64(4), object(7)
# memory usage: 1.4+ MB

# %%
for col in df.columns:
  print(f'{col}:\n', df[col].unique(), '\n')
# Out:
# Купил ли билет:
#  ['Yes' 'No']
#
# Среднегодовое число просмотра туристических сайтов:
#  [307. 367. 277. 247. 202. 240.  nan 225. 285. 270. 262. 217. 232. 255.
#  210. 165. 397. 180. 157. 330. 345. 292. 322. 375. 195. 360. 412. 382.
#  300. 405. 435. 150. 187.  42. 427. 352.  35. 450. 135. 308. 368. 249.
#  205. 445. 226. 287. 271. 263. 219. 234. 256. 212. 241. 399. 286. 182.
#  159. 316. 332. 347. 248. 331. 294. 323. 376. 265. 204. 309. 257. 346.
#  264. 361. 196. 278. 444. 272. 414. 339. 443. 233. 280. 422. 174. 384.
#  302. 242. 181. 211. 436. 279. 151. 377. 188. 189. 166. 406. 324. 197.
#  143. 167. 383. 227. 144. 301. 429. 203. 250. 413. 338. 310. 392. 317.
#  354. 400. 369. 137. 136. 295. 391. 353. 218. 362. 428. 451. 430. 173.
#  190. 398. 355. 437. 407. 152. 421. 158. 293. 235. 220. 340. 385. 370.
#  325. 415. 452. 315. 379. 290. 231. 281. 269. 222. 244. 221. 246. 402.
#  184. 276. 258. 168. 259. 404. 318. 333. 252. 304. 378. 273. 282. 253.
#  199. 215. 228. 356. 268. 366. 335. 266. 254. 274. 291. 448. 417. 455.
#  229. 236. 275. 349. 418. 425. 185. 389. 388. 411. 216. 446. 337. 283.
#  243. 154. 261. 289. 193. 175. 409. 326. 386. 207. 153. 172. 372. 390.
#  245. 313. 306. 230. 441. 176. 213. 433. 208. 387. 147. 342. 424. 148.
#  408. 303. 395. 209. 319. 373. 267. 296. 350. 341. 297. 239. 401. 454.
#  251. 299. 312. 344. 348. 305. 394. 238. 200. 363. 206. 420. 201. 284.
#  142. 374. 298. 357. 334. 179. 364. 321. 161. 431. 351. 381. 311. 393.
#  288. 329. 328. 192. 237. 214. 198. 396. 456. 327. 223. 458. 260. 141.
#  380. 191. 160. 224. 457. 359. 320. 423. 410. 194. 365. 177. 403. 438.
#  164. 170. 149. 138. 453. 169. 146. 447. 155. 162. 449. 439. 416. 145.
#  358. 371. 343. 140. 336. 183. 314. 426. 419. 186. 440. 459. 156. 163.
#  461. 178. 442. 432. 434. 462. 460. 171. 464. 463.]
#
# Предпочитаемое устройство для авторизации:
#  ['iOS and Android' 'iOS' 'ANDROID' nan 'Android' 'Android OS' 'Other'
#  'Others' 'Tab' 'Laptop' 'Mobile']
#
# Число лайков на связанные с туризмом публикации за последний год:
#  [38570.  9765. 48055. ...  5478. 35851. 22025.]
#
# Среднегодовое число туристических поездок:
#  ['1' '24' '23' '27' '16' '15' '26' '19' '21' '11' '10' '25' '12' '18' '29'
#  nan '22' '14' '20' '28' '17' '13' '*' '5' '8' '2' '3' '9' '7' '6' '4']
#
# Число членов семьи:
#  ['2' '1' '4' 'Three' '3' '5' '10']
#
# Предпочитаемый вид отдыха:
#  ['Financial' 'Other' 'Medical' nan 'Game' 'Social media' 'Entertainment'
#  'Tour and Travel' 'Movie' 'OTT' 'Tour  Travel' 'Beach' 'Historical site'
#  'Big Cities' 'Trekking' 'Hill Stations']
#
# Среднеговое число комментариев к связанным с туризмом публикациям:
#  [ 94.  61.  92.  56.  40.  79.  81.  67.  44.  84.  49.  31.  93.  50.
#   51.  80.  96.  78.  45.  82.  53.  83.  58.  72.  48.  42.  41.  86.
#   97.  75.  33.  37.  73.  nan  98.  47.  71.   3.  43.  99.  59.  95.
#   57.  76.  87.  66.  55.  32.  52.  70.  62.  64.  63.  60. 100.  46.
#   39.  77.  91.  54.  34.  90.  65.  36.  88.  35.  89.  68.  85.  69.
#   74.  38. 106. 105. 103. 108. 111. 104. 102. 109. 110. 112. 101. 107.
#  615. 114. 113. 215. 815. 685. 118. 117. 115. 116. 121. 122. 120. 124.
#  119. 125. 123.]
#
# Число лайков на туристические публикации пользователя:
#  [ 5993  5130  2090 ... 12093  9983  6203]
#
# Число прошедших после крайней поездки недель:
#  [ 8  1  6  9  0  4  5  2  7  3 10 11]
#
# Разегистрирован ли в «нашей» соцсети:
#  ['Yes' 'No' 'Yeso' nan '1' '0']
#
# Среднемесячное число лайков в «нашей» соцсети:
#  [ 11  23  15  12  13  20  22  21   4  17  14  16  18  19  24  25  30  29
#   28  27 376 381  26 427 437 499 363 425 439 301 461 322 324 355 338 332
#  459 460 453 300 474 368 352 445 310 323 490 371 444 343 417 393 463 350
#  432 412 379 336 441 346 317 406 485 400 483 478 438 354 313 497 325 419
#  388 398 378 397 349 356 420 347 500 442 435 447 484 330 326 360 403 465
#  365 353 429 345 321 491 476 475 487 316 428 472 314 405 473 339 342 455
#  469 399 422 370 361 467 458 304 410 383 466 446 302 486 333 418 351 391
#  468 454 329 390 384 404 402 424 488 440 312 449 477 380 357 414 337  33
#   32  31  34  35  36  37  40  38  41  39  43  42  45  44  47  46  48]
#
# Трудоустроен ли:
#  ['No' 'Yes' '0']
#
# Наличие интересующихся туризмом друзей (1 — много, 4 — мало):
#  [ 1  4  2  3 10]
#
# Подросток ли:
#  [ 0.  1.  3.  2. nan]
#
# Среднее время, проведённое в «нашей» соцсети:
#  [  8.  10.   7.   6.  12.   1.  17.  nan   5.   3.  31.  13.   0.  26.
#   24.  22.   9.  19.   2.  23.  14.  15.   4.  29.  28.  21.  25.  20.
#   11.  16.  37.  38.  30.  40.  18.  36.  34.  32.  33.  35.  27.  41.
#  135.  45.  43.  39.  44.  42. 170. 235. 270.  47.  46.]

# %% [markdown]
# В некоторых местах вместо цифры 3 написано слово Three. Где-то написано Android, а где-то — ANDROID. Все такого рода оплошности исправляются в ячейке кода ниже.

# %%
df['Предпочитаемое устройство для авторизации'].replace({'ANDROID': 'Android', \
  'Android OS': 'Android', 'Others': 'Other', \
  'Mobile': 'iOS and Android'}, inplace=True)

df['Предпочитаемый вид отдыха'].replace('Tour  Travel', 'Tour and Travel', \
  inplace=True)

df['Трудоустроен ли'].replace('0', 'No', inplace=True)

df['Разегистрирован ли в «нашей» соцсети'].replace({'Yeso': 'Yes', \
  '1': 'Yes', '0': 'No'}, inplace=True)

df['Число членов семьи'].replace('Three', '3', inplace=True)

df['Купил ли билет'].replace({'Yes': 1, 'No': 0}, inplace=True)

# %%
for col in df.columns:
  print(f'{col}:\n', df[col].unique(), '\n')
# Out:
# Купил ли билет:
#  [1 0]
#
# Среднегодовое число просмотра туристических сайтов:
#  [307. 367. 277. 247. 202. 240.  nan 225. 285. 270. 262. 217. 232. 255.
#  210. 165. 397. 180. 157. 330. 345. 292. 322. 375. 195. 360. 412. 382.
#  300. 405. 435. 150. 187.  42. 427. 352.  35. 450. 135. 308. 368. 249.
#  205. 445. 226. 287. 271. 263. 219. 234. 256. 212. 241. 399. 286. 182.
#  159. 316. 332. 347. 248. 331. 294. 323. 376. 265. 204. 309. 257. 346.
#  264. 361. 196. 278. 444. 272. 414. 339. 443. 233. 280. 422. 174. 384.
#  302. 242. 181. 211. 436. 279. 151. 377. 188. 189. 166. 406. 324. 197.
#  143. 167. 383. 227. 144. 301. 429. 203. 250. 413. 338. 310. 392. 317.
#  354. 400. 369. 137. 136. 295. 391. 353. 218. 362. 428. 451. 430. 173.
#  190. 398. 355. 437. 407. 152. 421. 158. 293. 235. 220. 340. 385. 370.
#  325. 415. 452. 315. 379. 290. 231. 281. 269. 222. 244. 221. 246. 402.
#  184. 276. 258. 168. 259. 404. 318. 333. 252. 304. 378. 273. 282. 253.
#  199. 215. 228. 356. 268. 366. 335. 266. 254. 274. 291. 448. 417. 455.
#  229. 236. 275. 349. 418. 425. 185. 389. 388. 411. 216. 446. 337. 283.
#  243. 154. 261. 289. 193. 175. 409. 326. 386. 207. 153. 172. 372. 390.
#  245. 313. 306. 230. 441. 176. 213. 433. 208. 387. 147. 342. 424. 148.
#  408. 303. 395. 209. 319. 373. 267. 296. 350. 341. 297. 239. 401. 454.
#  251. 299. 312. 344. 348. 305. 394. 238. 200. 363. 206. 420. 201. 284.
#  142. 374. 298. 357. 334. 179. 364. 321. 161. 431. 351. 381. 311. 393.
#  288. 329. 328. 192. 237. 214. 198. 396. 456. 327. 223. 458. 260. 141.
#  380. 191. 160. 224. 457. 359. 320. 423. 410. 194. 365. 177. 403. 438.
#  164. 170. 149. 138. 453. 169. 146. 447. 155. 162. 449. 439. 416. 145.
#  358. 371. 343. 140. 336. 183. 314. 426. 419. 186. 440. 459. 156. 163.
#  461. 178. 442. 432. 434. 462. 460. 171. 464. 463.]
#
# Предпочитаемое устройство для авторизации:
#  ['iOS and Android' 'iOS' 'Android' nan 'Other' 'Tab' 'Laptop']
#
# Число лайков на связанные с туризмом публикации за последний год:
#  [38570.  9765. 48055. ...  5478. 35851. 22025.]
#
# Среднегодовое число туристических поездок:
#  ['1' '24' '23' '27' '16' '15' '26' '19' '21' '11' '10' '25' '12' '18' '29'
#  nan '22' '14' '20' '28' '17' '13' '*' '5' '8' '2' '3' '9' '7' '6' '4']
#
# Число членов семьи:
#  ['2' '1' '4' '3' '5' '10']
#
# Предпочитаемый вид отдыха:
#  ['Financial' 'Other' 'Medical' nan 'Game' 'Social media' 'Entertainment'
#  'Tour and Travel' 'Movie' 'OTT' 'Beach' 'Historical site' 'Big Cities'
#  'Trekking' 'Hill Stations']
#
# Среднеговое число комментариев к связанным с туризмом публикациям:
#  [ 94.  61.  92.  56.  40.  79.  81.  67.  44.  84.  49.  31.  93.  50.
#   51.  80.  96.  78.  45.  82.  53.  83.  58.  72.  48.  42.  41.  86.
#   97.  75.  33.  37.  73.  nan  98.  47.  71.   3.  43.  99.  59.  95.
#   57.  76.  87.  66.  55.  32.  52.  70.  62.  64.  63.  60. 100.  46.
#   39.  77.  91.  54.  34.  90.  65.  36.  88.  35.  89.  68.  85.  69.
#   74.  38. 106. 105. 103. 108. 111. 104. 102. 109. 110. 112. 101. 107.
#  615. 114. 113. 215. 815. 685. 118. 117. 115. 116. 121. 122. 120. 124.
#  119. 125. 123.]
#
# Число лайков на туристические публикации пользователя:
#  [ 5993  5130  2090 ... 12093  9983  6203]
#
# Число прошедших после крайней поездки недель:
#  [ 8  1  6  9  0  4  5  2  7  3 10 11]
#
# Разегистрирован ли в «нашей» соцсети:
#  ['Yes' 'No' nan]
#
# Среднемесячное число лайков в «нашей» соцсети:
#  [ 11  23  15  12  13  20  22  21   4  17  14  16  18  19  24  25  30  29
#   28  27 376 381  26 427 437 499 363 425 439 301 461 322 324 355 338 332
#  459 460 453 300 474 368 352 445 310 323 490 371 444 343 417 393 463 350
#  432 412 379 336 441 346 317 406 485 400 483 478 438 354 313 497 325 419
#  388 398 378 397 349 356 420 347 500 442 435 447 484 330 326 360 403 465
#  365 353 429 345 321 491 476 475 487 316 428 472 314 405 473 339 342 455
#  469 399 422 370 361 467 458 304 410 383 466 446 302 486 333 418 351 391
#  468 454 329 390 384 404 402 424 488 440 312 449 477 380 357 414 337  33
#   32  31  34  35  36  37  40  38  41  39  43  42  45  44  47  46  48]
#
# Трудоустроен ли:
#  ['No' 'Yes']
#
# Наличие интересующихся туризмом друзей (1 — много, 4 — мало):
#  [ 1  4  2  3 10]
#
# Подросток ли:
#  [ 0.  1.  3.  2. nan]
#
# Среднее время, проведённое в «нашей» соцсети:
#  [  8.  10.   7.   6.  12.   1.  17.  nan   5.   3.  31.  13.   0.  26.
#   24.  22.   9.  19.   2.  23.  14.  15.   4.  29.  28.  21.  25.  20.
#   11.  16.  37.  38.  30.  40.  18.  36.  34.  32.  33.  35.  27.  41.
#  135.  45.  43.  39.  44.  42. 170. 235. 270.  47.  46.]

# %% [markdown]
# Удалим объект выборки (строку таблицы), которому в графу "среднегодовое число туристических поездок" приписали звёздочку.

# %%
df = df[df['Среднегодовое число туристических поездок'] != '*']

# %% [markdown]
# И вообще удалим все объекты выборки, у которых пропущены какие-либо значения признаков.

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-301-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %% [markdown]
# У признаков «Подросток ли» и «Наличие интересующихся туризмом друзей» тип данных изменим на `object`, у признака «Число членов семьи» — на `int`.

# %%
df = df.astype({'Подросток ли': object, \
  'Наличие интересующихся туризмом друзей (1 — много, 4 — мало)': object,
  'Число членов семьи': int,
  'Среднегодовое число туристических поездок': int})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10454 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Купил ли билет                                                     10454 non-null  int64
#  1   Среднегодовое число просмотра туристических сайтов                 10454 non-null  float64
#  2   Предпочитаемое устройство для авторизации                          10454 non-null  object
#  3   Число лайков на связанные с туризмом публикации за последний год   10454 non-null  float64
#  4   Среднегодовое число туристических поездок                          10454 non-null  int64
#  5   Число членов семьи                                                 10454 non-null  int64
#  6   Предпочитаемый вид отдыха                                          10454 non-null  object
#  7   Среднеговое число комментариев к связанным с туризмом публикациям  10454 non-null  float64
#  8   Число лайков на туристические публикации пользователя              10454 non-null  int64
#  9   Число прошедших после крайней поездки недель                       10454 non-null  int64
#  10  Разегистрирован ли в «нашей» соцсети                               10454 non-null  object
#  11  Среднемесячное число лайков в «нашей» соцсети                      10454 non-null  int64
#  12  Трудоустроен ли                                                    10454 non-null  object
#  13  Наличие интересующихся туризмом друзей (1 — много, 4 — мало)       10454 non-null  object
#  14  Подросток ли                                                       10454 non-null  object
#  15  Среднее время, проведённое в «нашей» соцсети                       10454 non-null  float64
# dtypes: float64(4), int64(6), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# Посмотрим на предпочтения пользователей соцсети в выборе мест отдыха.

# %%
preferred_loc = df['Предпочитаемый вид отдыха'].value_counts()
sns.barplot(x = preferred_loc.index, y = preferred_loc.values)
plt.title('Распределение пользователей соцсети по предпочитаемому виду отдыха', y=1.05)
plt.xticks(rotation=75);

# %% [markdown]
# Далее нам пригодится список категориальных признаков для One-Hot-Encoding.

# %%
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# Отделим признаки объектов от значений целевой переменной.

# %%
X = df.drop('Купил ли билет', axis=1)
y = df['Купил ли билет']

# %% [markdown]
# Применим к категориальным признаком One-Hot-Encoding.

# %%
X_ohe = pd.get_dummies(X, columns = categorical_columns, dtype='int')
pd.set_option('display.max_columns', None)
X_ohe.sample(10)
# Out:
#        Среднегодовое число просмотра туристических сайтов  \
# 10379                                              355.0
# 9200                                               187.0
# 6406                                               304.0
# 5601                                               233.0
# 2686                                               322.0
# 9644                                               323.0
# 5424                                               233.0
# 544                                                352.0
# 1455                                               300.0
# 2134                                               270.0
#
#        Число лайков на связанные с туризмом публикации за последний год  \
# 10379                                            23467.0
# 9200                                             48026.0
# 6406                                             14289.0
# 5601                                             38969.0
# 2686                                             41265.0
# 9644                                              6627.0
# 5424                                              6402.0
# 544                                               7595.0
# 1455                                             46270.0
# 2134                                             49875.0
#
#        Среднегодовое число туристических поездок  Число членов семьи  \
# 10379                                          9                   2
# 9200                                          10                   4
# 6406                                           2                   4
# 5601                                           1                   4
# 2686                                           1                   3
# 9644                                          29                   3
# 5424                                           1                   5
# 544                                            1                   3
# 1455                                           1                   4
# 2134                                          14                   1
#
#        Среднеговое число комментариев к связанным с туризмом публикациям  \
# 10379                                               81.0
# 9200                                                99.0
# 6406                                                92.0
# 5601                                                74.0
# 2686                                                73.0
# 9644                                                74.0
# 5424                                               108.0
# 544                                                 49.0
# 1455                                                52.0
# 2134                                                68.0
#
#        Число лайков на туристические публикации пользователя  \
# 10379                                               9676
# 9200                                                4317
# 6406                                                4564
# 5601                                                5525
# 2686                                                7847
# 9644                                                4329
# 5424                                               16477
# 544                                                13770
# 1455                                                2809
# 2134                                                6586
#
#        Число прошедших после крайней поездки недель  \
# 10379                                             2
# 9200                                              2
# 6406                                              1
# 5601                                              1
# 2686                                              1
# 9644                                              6
# 5424                                              5
# 544                                               9
# 1455                                              2
# 2134                                              0
#
#        Среднемесячное число лайков в «нашей» соцсети  \
# 10379                                             29
# 9200                                              19
# 6406                                              23
# 5601                                              18
# 2686                                              17
# 9644                                              35
# 5424                                              21
# 544                                               12
# 1455                                              14
# 2134                                              17
#
#        Среднее время, проведённое в «нашей» соцсети  \
# 10379                                          16.0
# 9200                                            8.0
# 6406                                           20.0
# 5601                                           15.0
# 2686                                           10.0
# 9644                                           22.0
# 5424                                           14.0
# 544                                            28.0
# 1455                                            8.0
# 2134                                           17.0
#
#        Предпочитаемое устройство для авторизации_Android  \
# 10379                                                  0
# 9200                                                   0
# 6406                                                   0
# 5601                                                   0
# 2686                                                   0
# 9644                                                   0
# 5424                                                   0
# 544                                                    0
# 1455                                                   0
# 2134                                                   0
#
#        Предпочитаемое устройство для авторизации_Laptop  \
# 10379                                                 0
# 9200                                                  0
# 6406                                                  0
# 5601                                                  0
# 2686                                                  0
# 9644                                                  0
# 5424                                                  0
# 544                                                   0
# 1455                                                  0
# 2134                                                  0
#
#        Предпочитаемое устройство для авторизации_Other  \
# 10379                                                0
# 9200                                                 0
# 6406                                                 0
# 5601                                                 0
# 2686                                                 0
# 9644                                                 0
# 5424                                                 0
# 544                                                  0
# 1455                                                 0
# 2134                                                 0
#
#        Предпочитаемое устройство для авторизации_Tab  \
# 10379                                              1
# 9200                                               1
# 6406                                               1
# 5601                                               0
# 2686                                               0
# 9644                                               1
# 5424                                               0
# 544                                                0
# 1455                                               0
# 2134                                               0
#
#        Предпочитаемое устройство для авторизации_iOS  \
# 10379                                              0
# 9200                                               0
# 6406                                               0
# 5601                                               0
# 2686                                               0
# 9644                                               0
# 5424                                               0
# 544                                                1
# 1455                                               0
# 2134                                               0
#
#        Предпочитаемое устройство для авторизации_iOS and Android  \
# 10379                                                  0
# 9200                                                   0
# 6406                                                   0
# 5601                                                   1
# 2686                                                   1
# 9644                                                   0
# 5424                                                   1
# 544                                                    0
# 1455                                                   1
# 2134                                                   1
#
#        Предпочитаемый вид отдыха_Beach  Предпочитаемый вид отдыха_Big Cities  \
# 10379                                0                                     0
# 9200                                 0                                     1
# 6406                                 0                                     0
# 5601                                 0                                     0
# 2686                                 0                                     0
# 9644                                 0                                     0
# 5424                                 0                                     0
# 544                                  0                                     0
# 1455                                 0                                     0
# 2134                                 0                                     0
#
#        Предпочитаемый вид отдыха_Entertainment  \
# 10379                                        0
# 9200                                         0
# 6406                                         0
# 5601                                         0
# 2686                                         0
# 9644                                         0
# 5424                                         0
# 544                                          0
# 1455                                         0
# 2134                                         0
#
#        Предпочитаемый вид отдыха_Financial  Предпочитаемый вид отдыха_Game  \
# 10379                                    0                               0
# 9200                                     0                               0
# 6406                                     0                               0
# 5601                                     1                               0
# 2686                                     0                               0
# 9644                                     0                               0
# 5424                                     1                               0
# 544                                      0                               0
# 1455                                     1                               0
# 2134                                     1                               0
#
#        Предпочитаемый вид отдыха_Hill Stations  \
# 10379                                        0
# 9200                                         0
# 6406                                         0
# 5601                                         0
# 2686                                         0
# 9644                                         0
# 5424                                         0
# 544                                          0
# 1455                                         0
# 2134                                         0
#
#        Предпочитаемый вид отдыха_Historical site  \
# 10379                                          1
# 9200                                           0
# 6406                                           0
# 5601                                           0
# 2686                                           0
# 9644                                           1
# 5424                                           0
# 544                                            0
# 1455                                           0
# 2134                                           0
#
#        Предпочитаемый вид отдыха_Medical  Предпочитаемый вид отдыха_Movie  \
# 10379                                  0                                0
# 9200                                   0                                0
# 6406                                   0                                0
# 5601                                   0                                0
# 2686                                   1                                0
# 9644                                   0                                0
# 5424                                   0                                0
# 544                                    1                                0
# 1455                                   0                                0
# 2134                                   0                                0
#
#        Предпочитаемый вид отдыха_OTT  Предпочитаемый вид отдыха_Other  \
# 10379                              0                                0
# 9200                               0                                0
# 6406                               0                                0
# 5601                               0                                0
# 2686                               0                                0
# 9644                               0                                0
# 5424                               0                                0
# 544                                0                                0
# 1455                               0                                0
# 2134                               0                                0
#
#        Предпочитаемый вид отдыха_Social media  \
# 10379                                       0
# 9200                                        0
# 6406                                        0
# 5601                                        0
# 2686                                        0
# 9644                                        0
# 5424                                        0
# 544                                         0
# 1455                                        0
# 2134                                        0
#
#        Предпочитаемый вид отдыха_Tour and Travel  \
# 10379                                          0
# 9200                                           0
# 6406                                           0
# 5601                                           0
# 2686                                           0
# 9644                                           0
# 5424                                           0
# 544                                            0
# 1455                                           0
# 2134                                           0
#
#        Предпочитаемый вид отдыха_Trekking  \
# 10379                                   0
# 9200                                    0
# 6406                                    1
# 5601                                    0
# 2686                                    0
# 9644                                    0
# 5424                                    0
# 544                                     0
# 1455                                    0
# 2134                                    0
#
#        Разегистрирован ли в «нашей» соцсети_No  \
# 10379                                        1
# 9200                                         0
# 6406                                         1
# 5601                                         1
# 2686                                         0
# 9644                                         1
# 5424                                         1
# 544                                          0
# 1455                                         1
# 2134                                         0
#
#        Разегистрирован ли в «нашей» соцсети_Yes  Трудоустроен ли_No  \
# 10379                                         0                   1
# 9200                                          1                   1
# 6406                                          0                   1
# 5601                                          0                   1
# 2686                                          1                   1
# 9644                                          0                   1
# 5424                                          0                   1
# 544                                           1                   1
# 1455                                          0                   1
# 2134                                          1                   1
#
#        Трудоустроен ли_Yes  \
# 10379                    0
# 9200                     0
# 6406                     0
# 5601                     0
# 2686                     0
# 9644                     0
# 5424                     0
# 544                      0
# 1455                     0
# 2134                     0
#
#        Наличие интересующихся туризмом друзей (1 — много, 4 — мало)_1  \
# 10379                                                  0
# 9200                                                   0
# 6406                                                   1
# 5601                                                   1
# 2686                                                   1
# 9644                                                   1
# 5424                                                   0
# 544                                                    0
# 1455                                                   0
# 2134                                                   1
#
#        Наличие интересующихся туризмом друзей (1 — много, 4 — мало)_2  \
# 10379                                                  0
# 9200                                                   0
# 6406                                                   0
# 5601                                                   0
# 2686                                                   0
# 9644                                                   0
# 5424                                                   0
# 544                                                    0
# 1455                                                   0
# 2134                                                   0
#
#        Наличие интересующихся туризмом друзей (1 — много, 4 — мало)_3  \
# 10379                                                  0
# 9200                                                   0
# 6406                                                   0
# 5601                                                   0
# 2686                                                   0
# 9644                                                   0
# 5424                                                   1
# 544                                                    0
# 1455                                                   0
# 2134                                                   0
#
#        Наличие интересующихся туризмом друзей (1 — много, 4 — мало)_4  \
# 10379                                                  1
# 9200                                                   1
# 6406                                                   0
# 5601                                                   0
# 2686                                                   0
# 9644                                                   0
# 5424                                                   0
# 544                                                    1
# 1455                                                   1
# 2134                                                   0
#
#        Подросток ли_0.0  Подросток ли_1.0  Подросток ли_2.0  Подросток ли_3.0
# 10379                 1                 0                 0                 0
# 9200                  0                 1                 0                 0
# 6406                  1                 0                 0                 0
# 5601                  0                 0                 1                 0
# 2686                  0                 1                 0                 0
# 9644                  1                 0                 0                 0
# 5424                  1                 0                 0                 0
# 544                   0                 0                 1                 0
# 1455                  1                 0                 0                 0
# 2134                  0                 1                 0                 0

# %%
features = X_ohe.columns

# %%
from sklearn.preprocessing import MinMaxScaler
minmaxscaler = MinMaxScaler()
X_ohe = minmaxscaler.fit_transform(X_ohe)

# %% [markdown]
# # 2. Логистическая регрессия

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegressionCV

log_reg = LogisticRegressionCV(class_weight = 'balanced')
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
recall = recall_score(y_test, y_pred)
print(recall)
# Out:
# 0.7011834319526628

# %%
features_importance = pd.DataFrame()
features_importance['Features'] = features
features_importance['Coefficients'] = log_reg.coef_.T
features_importance.sort_values(by = 'Coefficients', ascending=False, inplace=True)

# %% [markdown]
# ---
#
#
# На графике ниже отразим степень влияния тех или иных характеристик пользователя на вероятность покупки им билета в следующем месяце. Высокий столбец, смотрящий вверх, говорит о том, что наличие данного признака у пользователя сильно повышает вероятность покупки им билета. Высокий столбец, смотрящий вниз, обратно, символизирует, что пользователь, характеризующийся данным признаком, с высокой вероятностью ***не*** купит билет в следующем месяце.
#
#
# ---

# %%
fig, ax = plt.subplots(figsize=(34, 5))

sns.barplot(x = features_importance['Features'],\
            y = features_importance['Coefficients'], ax=ax,\
            )

plt.title('Влияние тех или иных признаков пользователя на вероятность\
покупки билета', y=1.05)
plt.xlabel('Характеристики пользователя')
plt.ylabel('Влияние характеристики на вероятность покупки')
plt.xticks(rotation=75)

ax.grid(True);

# %% [markdown]
# # 3. Случайный лес

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
random_forest = RandomForestClassifier(n_estimators=100, max_depth=50, random_state=0)
random_forest.fit(X_train, y_train)
random_forest_preds = random_forest.predict(X_test)
print("Метрики качества классификации методом случайного леса:\n", \
      classification_report(y_test, random_forest_preds))
# Out:
# Метрики качества классификации методом случайного леса:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1753
#            1       1.00      0.90      0.95       338
#
#     accuracy                           0.98      2091
#    macro avg       0.99      0.95      0.97      2091
# weighted avg       0.98      0.98      0.98      2091

# %% [markdown]
# # 4. XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
xgb_preds = xgb.predict(X_test)
print("Метрики качества классификации методом экстремального градиентного\
бустинга:\n", classification_report(y_test, xgb_preds))
# Out:
# Метрики качества классификации методом экстремального градиентногобустинга:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1753
#            1       1.00      0.96      0.98       338
#
#     accuracy                           0.99      2091
#    macro avg       1.00      0.98      0.99      2091
# weighted avg       0.99      0.99      0.99      2091
